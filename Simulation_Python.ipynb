# %%
import pandas as pd

# %% [markdown]
# cara membaca/import file csv

# %%
salary= pd.read_csv('salary_dataset_2.csv')
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 610 entries, 0 to 609
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           610 non-null    int64
#  1   experience_level    610 non-null    object
#  2   employment_type     610 non-null    object
#  3   job_title           610 non-null    object
#  4   salary              609 non-null    object
#  5   salary_currency     610 non-null    object
#  6   salary_in_usd       609 non-null    float64
#  7   employee_residence  610 non-null    object
#  8   remote_ratio        610 non-null    int64
#  9   company_location    610 non-null    object
#  10  company_size        610 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 52.5+ KB

# %% [markdown]
# 1. cek duplicate
# 2. cek data kosong
# 3. cek data error
# 4. cek outliers
# 5. change datatype

# %%
salary_backup = salary.copy()

# %%
salary
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Developer
# 2         2020               SE              FT               Data Engineer
# 3         2020               MI              FT                Data Analyst
# 4         2020               SE              FT  Machine Learning Developer
# ..         ...              ...             ...                         ...
# 605       2022               SE              FT               Data Engineer
# 606       2022               SE              FT               Data Engineer
# 607       2022               SE              FT                Data Analyst
# 608       2022               SE              FT                Data Analyst
# 609       2022               MI              FT              Data Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR        79833.0                 DE             0
# 1    260000             USD       260000.0                 JP             0
# 2     85000             GBP       109024.0                 GB            50
# 3     20000             USD        20000.0                 HN             0
# 4    150000             USD       150000.0                 US            50
# ..      ...             ...            ...                ...           ...
# 605  154000             USD       154000.0                 US           100
# 606  126000             USD       126000.0                 US           100
# 607  129000             USD       129000.0                 US             0
# 608  150000             USD       150000.0                 US           100
# 609  200000             USD       200000.0                 IN           100
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 605               US            M
# 606               US            M
# 607               US            M
# 608               US            M
# 609               US            L
#
# [610 rows x 11 columns]

# %% [markdown]
# 1. Drop Duplicates

# %%
salary[salary.duplicated()]
# Out:
#      work_year experience_level employment_type                   job_title  \
# 217       2021               MI              FT              Data Scientist
# 243       2021               SE              FT              Data Scientist
# 251       2021               EN              FT              Data Scientist
# 256       2021               MI              FT               Data Engineer
# 333       2022               SE              FT                Data Analyst
# 334       2022               SE              FT                Data Analyst
# 335       2022               SE              FT                Data Analyst
# 355       2022               SE              FT              Data Scientist
# 364       2022               SE              FT                Data Analyst
# 365       2022               SE              FT                Data Analyst
# 372       2022               SE              FT              Data Scientist
# 376       2022               MI              FT               Data Engineer
# 379       2022               SE              FT               Data Engineer
# 387       2022               SE              FT               Data Engineer
# 394       2022               SE              FT                Data Analyst
# 395       2022               SE              FT                Data Analyst
# 408       2022               MI              FT                Data Analyst
# 440       2022               SE              FT  Machine Learning Developer
# 441       2022               SE              FT  Machine Learning Developer
# 445       2022               MI              FT               Data Engineer
# 448       2022               SE              FT               Data Engineer
# 449       2022               SE              FT               Data Engineer
# 475       2022               SE              FT              Data Scientist
# 529       2022               SE              FT                Data Analyst
# 531       2022               SE              FT                Data Analyst
# 538       2022               SE              FT                Data Analyst
# 539       2022               SE              FT               Data Engineer
# 547       2022               SE              FT               Data Engineer
# 549       2022               SE              FT               Data Engineer
# 553       2022               SE              FT              Data Scientist
# 557       2022               SE              FT               Data Engineer
# 568       2022               SE              FT                Data Analyst
# 571       2022               SE              FT              Data Scientist
# 573       2022               SE              FT              Data Scientist
# 574       2022               SE              FT                Data Analyst
# 576       2022               SE              FT              Data Scientist
# 577       2022               SE              FT              Data Scientist
# 578       2022               SE              FT              Data Scientist
# 580       2022               SE              FT               Data Engineer
# 589       2022               SE              FT              Data Scientist
# 590       2022               SE              FT                Data Analyst
# 594       2022               SE              FT              Data Scientist
# 597       2022               SE              FT                Data Analyst
# 598       2022               SE              FT              Data Scientist
# 599       2022               SE              FT                Data Analyst
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 217   76760             EUR        90734.0                 DE            50
# 243  165000             USD       165000.0                 US           100
# 251   90000             USD        90000.0                 US           100
# 256  200000             USD       200000.0                 US           100
# 333   90320             USD        90320.0                 US           100
# 334  112900             USD       112900.0                 US           100
# 335   90320             USD        90320.0                 US           100
# 355  123000             USD       123000.0                 US           100
# 364  130000             USD       130000.0                 CA           100
# 365   61300             USD        61300.0                 CA           100
# 372  123000             USD       123000.0                 US           100
# 376   50000             EUR        54957.0                 GR             0
# 379  165400             USD       165400.0                 US           100
# 387  132320             USD       132320.0                 US           100
# 394  112900             USD       112900.0                 US           100
# 395   90320             USD        90320.0                 US           100
# 408   58000             USD        58000.0                 US             0
# 440  189650             USD       189650.0                 US             0
# 441  164996             USD       164996.0                 US             0
# 445   60000             GBP        78526.0                 GB           100
# 448  209100             USD       209100.0                 US           100
# 449  154600             USD       154600.0                 US           100
# 475  140000             USD       140000.0                 US           100
# 529  135000             USD       135000.0                 US           100
# 531   90320             USD        90320.0                 US           100
# 538  112900             USD       112900.0                 US           100
# 539  155000             USD       155000.0                 US           100
# 547  115000             USD       115000.0                 US           100
# 549  130000             USD       130000.0                 US           100
# 553  140400             USD       140400.0                 US             0
# 557  160000             USD       160000.0                 US           100
# 568  170000             USD       170000.0                 US           100
# 571  140000             USD       140000.0                 US           100
# 573  140000             USD       140000.0                 US           100
# 574  100000             USD       100000.0                 US           100
# 576  210000             USD       210000.0                 US           100
# 577  140000             USD       140000.0                 US           100
# 578  210000             USD       210000.0                 US           100
# 580  100000             USD       100000.0                 US           100
# 589  140000             USD       140000.0                 US           100
# 590   99000             USD        99000.0                 US             0
# 594  230000             USD       230000.0                 US           100
# 597  109280             USD       109280.0                 US           100
# 598  210000             USD       210000.0                 US           100
# 599  170000             USD       170000.0                 US           100
#
#     company_location company_size
# 217               DE            L
# 243               US            L
# 251               US            S
# 256               US            L
# 333               US            M
# 334               US            M
# 335               US            M
# 355               US            M
# 364               CA            M
# 365               CA            M
# 372               US            M
# 376               GR            M
# 379               US            M
# 387               US            M
# 394               US            M
# 395               US            M
# 408               US            S
# 440               US            M
# 441               US            M
# 445               GB            M
# 448               US            L
# 449               US            L
# 475               US            M
# 529               US            M
# 531               US            M
# 538               US            M
# 539               US            M
# 547               US            M
# 549               US            M
# 553               US            L
# 557               US            M
# 568               US            M
# 571               US            M
# 573               US            M
# 574               US            M
# 576               US            M
# 577               US            M
# 578               US            M
# 580               US            M
# 589               US            M
# 590               US            M
# 594               US            M
# 597               US            M
# 598               US            M
# 599               US            M

# %%
salary=salary.drop_duplicates()

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 565 entries, 0 to 609
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           565 non-null    int64
#  1   experience_level    565 non-null    object
#  2   employment_type     565 non-null    object
#  3   job_title           565 non-null    object
#  4   salary              564 non-null    object
#  5   salary_currency     565 non-null    object
#  6   salary_in_usd       564 non-null    float64
#  7   employee_residence  565 non-null    object
#  8   remote_ratio        565 non-null    int64
#  9   company_location    565 non-null    object
#  10  company_size        565 non-null    object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 53.0+ KB

# %%
salary[salary.duplicated()]
# Out:
# Empty DataFrame
# Columns: [work_year, experience_level, employment_type, job_title, salary, salary_currency, salary_in_usd, employee_residence, remote_ratio, company_location, company_size]
# Index: []

# %% [markdown]
# 2. Handle Missing Data

# %%
salary.isna().sum()
# Out:
# work_year             0
# experience_level      0
# employment_type       0
# job_title             0
# salary                1
# salary_currency       0
# salary_in_usd         1
# employee_residence    0
# remote_ratio          0
# company_location      0
# company_size          0
# dtype: int64

# %%
salary = salary[~salary['salary'].isna()]
salary = salary[~salary['salary_in_usd'].isna()]

# %% [markdown]
# 3. Remove irrelevant Data/Column

# %%
salary = salary.drop('salary', axis=1)
salary = salary.drop('salary_currency', axis=1)
salary
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Developer
# 2         2020               SE              FT               Data Engineer
# 3         2020               MI              FT                Data Analyst
# 4         2020               SE              FT  Machine Learning Developer
# ..         ...              ...             ...                         ...
# 605       2022               SE              FT               Data Engineer
# 606       2022               SE              FT               Data Engineer
# 607       2022               SE              FT                Data Analyst
# 608       2022               SE              FT                Data Analyst
# 609       2022               MI              FT              Data Scientist
#
#      salary_in_usd employee_residence  remote_ratio company_location  \
# 0          79833.0                 DE             0               DE
# 1         260000.0                 JP             0               JP
# 2         109024.0                 GB            50               GB
# 3          20000.0                 HN             0               HN
# 4         150000.0                 US            50               US
# ..             ...                ...           ...              ...
# 605       154000.0                 US           100               US
# 606       126000.0                 US           100               US
# 607       129000.0                 US             0               US
# 608       150000.0                 US           100               US
# 609       200000.0                 IN           100               US
#
#     company_size
# 0              L
# 1              S
# 2              M
# 3              S
# 4              L
# ..           ...
# 605            M
# 606            M
# 607            M
# 608            M
# 609            L
#
# [564 rows x 9 columns]

# %% [markdown]
# 4. Replace value (optional)

# %%
salary['experience_level'] = salary['experience_level'].replace('EN','Junior')
salary['experience_level'] = salary['experience_level'].replace('MI','Intermediate')
salary['experience_level'] = salary['experience_level'].replace('SE','Expert')
salary['experience_level'] = salary['experience_level'].replace('EX','Director')

salary['employment_type'] = salary['employment_type'].replace('FT','Full-Time')
salary['employment_type'] = salary['employment_type'].replace('PT','Part-Time')
salary['employment_type'] = salary['employment_type'].replace('CT','Contract')
salary['employment_type'] = salary['employment_type'].replace('FL','Freelance')

salary['company_size'] = salary['company_size'].replace('S','Small')
salary['company_size'] = salary['company_size'].replace('M','Medium')
salary['company_size'] = salary['company_size'].replace('L','Large')

salary['remote_ratio'] = salary['remote_ratio'].replace(0,'WFO')
salary['remote_ratio'] = salary['remote_ratio'].replace(50,'Hybrid')
salary['remote_ratio'] = salary['remote_ratio'].replace(100,'WFH')

# %%
salary['employee_residence'].unique()
# Out:
# array(['DE', 'JP', 'GB', 'HN', 'US', 'HU', 'NZ', 'FR', 'IN', 'PK', 'PL',
#        'PT', 'CN', 'GR', 'AE', 'NL', 'MX', 'CA', 'AT', 'NG', 'PH', 'ES',
#        'DK', 'RU', 'IT', 'HR', 'BG', 'SG', 'BR', 'IQ', 'VN', 'BE', 'UA',
#        'MT', 'CL', 'RO', 'IR', 'CO', 'MD', 'KE', 'SI', 'HK', 'TR', 'RS',
#        'PR', 'LU', 'JE', 'CZ', 'AR', 'DZ', 'TN', 'MY', 'EE', 'AU', 'BO',
#        'IE', 'CH'], dtype=object)

# %%
salary
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020     Intermediate       Full-Time              Data Scientist
# 1         2020           Expert       Full-Time  Machine Learning Developer
# 2         2020           Expert       Full-Time               Data Engineer
# 3         2020     Intermediate       Full-Time                Data Analyst
# 4         2020           Expert       Full-Time  Machine Learning Developer
# ..         ...              ...             ...                         ...
# 605       2022           Expert       Full-Time               Data Engineer
# 606       2022           Expert       Full-Time               Data Engineer
# 607       2022           Expert       Full-Time                Data Analyst
# 608       2022           Expert       Full-Time                Data Analyst
# 609       2022     Intermediate       Full-Time              Data Scientist
#
#      salary_in_usd employee_residence remote_ratio company_location  \
# 0          79833.0                 DE          WFO               DE
# 1         260000.0                 JP          WFO               JP
# 2         109024.0                 GB       Hybrid               GB
# 3          20000.0                 HN          WFO               HN
# 4         150000.0                 US       Hybrid               US
# ..             ...                ...          ...              ...
# 605       154000.0                 US          WFH               US
# 606       126000.0                 US          WFH               US
# 607       129000.0                 US          WFO               US
# 608       150000.0                 US          WFH               US
# 609       200000.0                 IN          WFH               US
#
#     company_size
# 0          Large
# 1          Small
# 2         Medium
# 3          Small
# 4          Large
# ..           ...
# 605       Medium
# 606       Medium
# 607       Medium
# 608       Medium
# 609        Large
#
# [564 rows x 9 columns]

# %% [markdown]
# 5. Check Outliers

# %%
#before
salary.boxplot(column='salary_in_usd')

# %%
salary['salary_in_usd'].describe()
# Out:
# count       564.000000
# mean     110869.794326
# std       72498.867056
# min        2859.000000
# 25%       60567.750000
# 50%      100000.000000
# 75%      150000.000000
# max      600000.000000
# Name: salary_in_usd, dtype: float64

# %% [markdown]
# Batas atas = Q3 + 1.5 X (Q3-Q1),
# Batas bawah = Q1 - 1.5 X (Q3-Q1)

# %%
q1 = salary['salary_in_usd'].quantile(0.25)
q3 = salary['salary_in_usd'].quantile(0.75)
upper_limit = q3 + (1.5 * (q3-q1))
lower_limit = q1 - (1.5 * (q3-q1))

# %%
salary = salary[salary['salary_in_usd'] > lower_limit]
salary = salary[salary['salary_in_usd'] < upper_limit]
salary['salary_in_usd'].describe()
# Out:
# count       554.000000
# mean     105316.902527
# std       59250.868192
# min        2859.000000
# 25%       60000.000000
# 50%      100000.000000
# 75%      146750.000000
# max      276000.000000
# Name: salary_in_usd, dtype: float64

# %%
#after
salary.boxplot(column='salary_in_usd')

# %%
salary.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 554 entries, 0 to 609
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           554 non-null    int64
#  1   experience_level    554 non-null    object
#  2   employment_type     554 non-null    object
#  3   job_title           554 non-null    object
#  4   salary_in_usd       554 non-null    float64
#  5   employee_residence  554 non-null    object
#  6   remote_ratio        554 non-null    object
#  7   company_location    554 non-null    object
#  8   company_size        554 non-null    object
# dtypes: float64(1), int64(1), object(7)
# memory usage: 43.3+ KB

# %%
salary
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020     Intermediate       Full-Time              Data Scientist
# 1         2020           Expert       Full-Time  Machine Learning Developer
# 2         2020           Expert       Full-Time               Data Engineer
# 3         2020     Intermediate       Full-Time                Data Analyst
# 4         2020           Expert       Full-Time  Machine Learning Developer
# ..         ...              ...             ...                         ...
# 605       2022           Expert       Full-Time               Data Engineer
# 606       2022           Expert       Full-Time               Data Engineer
# 607       2022           Expert       Full-Time                Data Analyst
# 608       2022           Expert       Full-Time                Data Analyst
# 609       2022     Intermediate       Full-Time              Data Scientist
#
#      salary_in_usd employee_residence remote_ratio company_location  \
# 0          79833.0                 DE          WFO               DE
# 1         260000.0                 JP          WFO               JP
# 2         109024.0                 GB       Hybrid               GB
# 3          20000.0                 HN          WFO               HN
# 4         150000.0                 US       Hybrid               US
# ..             ...                ...          ...              ...
# 605       154000.0                 US          WFH               US
# 606       126000.0                 US          WFH               US
# 607       129000.0                 US          WFO               US
# 608       150000.0                 US          WFH               US
# 609       200000.0                 IN          WFH               US
#
#     company_size
# 0          Large
# 1          Small
# 2         Medium
# 3          Small
# 4          Large
# ..           ...
# 605       Medium
# 606       Medium
# 607       Medium
# 608       Medium
# 609        Large
#
# [554 rows x 9 columns]

# %%
salary.to_csv('salary_cleaned.csv')

from google.colab import files
files.download('salary_cleaned.csv')
